# %% [markdown]
# # Task 1

# %% [markdown]
# ### Import Math_utils.py

# %%
## import importlib I have to import this there after importlib.reload('Module Nme')
from Math_utils import square
import Math_utils

square_result = square(5)
print("Square Of 5  is:",square_result)

addition_result = Math_utils.add(2,3)
print("Addition of 2 and 3 is:", addition_result)
# Out:
# Square Of 5  is: 25
# Addition of 2 and 3 is: 5

# %% [markdown]
# # Task 2

# %% [markdown]
# ### Import string_utils.py

# %%
import importlib

import string_utils 
from string_utils import *
importlib.reload(string_utils)
capitalized_word = string_utils.capitalizeword("hello")
print(capitalized_word)
reverse_word = string_utils.reversestring("Love")
print(f"Reverse word is: {reverse_word}")

total_number_of_word =  string_utils.word_count("Tanusree")
print(f"Total Number of word is: {total_number_of_word}")
# Out:
# Hello
# Reverse word is: evoL
# Total Number of word is: 8

# %% [markdown]
# # Task 3

# %% [markdown]
# ## Create Simple Package shop Package

# %%
# 1️ Import discount module as disc
import shop_package.discount as disc

# 2️ Import calculate_total from billing
from shop_package.billing import calculate_total

# 3️ Call every function

# Discount functions
print("Apply Discount:", disc.apply_discount(1000, 10))


# Billing function
print("Total:", calculate_total([100, 200, 300]))
# Out:
# Apply Discount: 900.0
# Flat Discount: 950
# Total: 600
